# %%
#convert csv to parquet
import pandas as pd
df = pd.read_csv('C:/Praxis/Term2/PROJECT/sqlserverDB.csv')
df.to_parquet('C:/Praxis/Term2/PROJECT/sample3.parquet')
readParquet = pd.read_parquet('C:/Praxis/Term2/PROJECT/sample3.parquet',engine ='pyarrow')
readParquet.head()
# Out:
#    UID              Name  Gender          State         City  Age  \
# 0  101   Sarika Bhardwaj  Female  Uttar Pradesh      Mathura   21
# 1  102            Swarup    Male         Odisha  Bhubaneswar   21
# 2  103  Mrs.Nishu Tiwari  Female             UP     Bareilly   54
# 3  104   Mantu Nath Roy     Male    West Bengal  Coochbehar    55
# 4  105        Deepshikha  Female  Uttar Pradesh     Varanasi   21
#
#   TakenVaccine VaccineName\n  CowinRefID FirstDoseSideEffects FirstDoseDate  \
# 0          Yes    Covishield  77328597.0          Yes, mildly    02-03-2021
# 1          Yes       Covaxin  48145206.0          Yes, mildly    01-02-2022
# 2          Yes    Covishield  58335779.0          Yes, mildly    08-25-2021
# 3          Yes    Covishield  97432837.0                   No    12-15-2021
# 4          Yes       Covaxin    870067.0                   No    10-19-2021
#
#   SecondDoseStatus SecondDoseDate SecondDoseSideEffects PositiveAfterVaccine  \
# ...
